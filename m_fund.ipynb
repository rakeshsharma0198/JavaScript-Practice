# %% [markdown]
# <a href="https://colab.research.google.com/github/rakeshsharma0198/JavaScript-Practice/blob/master/m_fund.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/data_2009_05_16.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Scheme Code                  130 non-null    int64
#  1   Scheme Name                  130 non-null    object
#  2   ISIN Div Payout/ISIN Growth  62 non-null     object
#  3   ISIN Div Reinvestment        64 non-null     object
#  4   Net Asset Value              130 non-null    object
#  5   Repurchase Price             130 non-null    object
#  6   Sale Price                   130 non-null    object
#  7   Date                         130 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 8.2+ KB

# %%
df.head()
# Out:
#    Scheme Code                                        Scheme Name  \
# 0       108794                  IDFC Liquid Fund - Daily Dividend
# 1       108793                          IDFC Liquid Fund - Growth
# 2       108796                IDFC Liquid Fund - Monthly Dividend
# 3       108795                   IDFC Liquid Fund-Weekly Dividend
# 4       100198  ING Liquid Fund-Institutional Daily Dividend O...
#
#   ISIN Div Payout/ISIN Growth ISIN Div Reinvestment Net Asset Value  \
# 0                INF194K01GJ9          INF194K01GI1       1000.2100
# 1                INF194K01GE0                   NaN       1248.0431
# 2                INF194K01GG5          INF194K01GF7       1002.6261
# 3                INF194K01GM3          INF194K01GL5       1000.3309
# 4                INF084M01473                   NaN         10.0121
#
#   Repurchase Price Sale Price        Date
# 0        1000.2100  1000.2100  2009-05-16
# 1        1248.0431  1248.0431  2009-05-16
# ...

# %%
import pandas as pd
print(pd.options.display.min_rows)
# Out:
# 10

# %%
import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd

df = pd.read_csv('/content/data_2009_05_16.csv')
print(df.head(5))
# Out:
#    Scheme Code                                        Scheme Name  \
# 0       108794                  IDFC Liquid Fund - Daily Dividend
# 1       108793                          IDFC Liquid Fund - Growth
# 2       108796                IDFC Liquid Fund - Monthly Dividend
# 3       108795                   IDFC Liquid Fund-Weekly Dividend
# 4       100198  ING Liquid Fund-Institutional Daily Dividend O...
#
#   ISIN Div Payout/ISIN Growth ISIN Div Reinvestment Net Asset Value  \
# 0                INF194K01GJ9          INF194K01GI1       1000.2100
# 1                INF194K01GE0                   NaN       1248.0431
# 2                INF194K01GG5          INF194K01GF7       1002.6261
# 3                INF194K01GM3          INF194K01GL5       1000.3309
# 4                INF084M01473                   NaN         10.0121
#
#   Repurchase Price Sale Price        Date
# 0        1000.2100  1000.2100  2009-05-16
# 1        1248.0431  1248.0431  2009-05-16
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data_2009_05_16.csv')

df.plot()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/data_2009_05_16.csv')

df.plot()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data_2009_05_16.csv')

df.plot(kind = 'scatter', x = 'Scheme Code', y = 'Sale Price')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data_2009_05_16.csv')

df.plot(kind = 'scatter', x = 'Scheme Code', y = 'Sale Price')

plt.show()

# %%
 import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data_2009_05_16.csv')
df.plot.barh(stacked=True);
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data_2009_05_16.csv')
df.plot.box();
plt.show()

# %%
 df.plot(subplots=True, figsize=(6, 6));
